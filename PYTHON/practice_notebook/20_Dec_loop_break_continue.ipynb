# %%
l = ["name","emailid","phoneno","address"]

# %%
for i in l:
    print(i +"prabhat")
# Out:
# nameprabhat
# emailidprabhat
# phonenoprabhat
# addressprabhat

# %%
s ="ineuron"
for i in s:
    print(i)
# Out:
# i
# n
# e
# u
# r
# o
# n

# %% [markdown]
# # for else kind of statement

# %%
l
# Out:
# ['name', 'emailid', 'phoneno', 'address']

# %%
for i in l:
    print(i)
else :
    print("if fofr loop is not going to complete itself")
# Out:
# name
# emailid
# phoneno
# address
# if fofr loop is not going to complete itself

# %%
l
# Out:
# ['name', 'emailid', 'phoneno', 'address']

# %%
#if for loop is not going throihj parse each and ever elemenmt then it will  ot wo in
#else loop
for i in l:
    if i =="emailid":
        break
    print(i)
else :
    print("check this statement")
# Out:
# name

# %%
s = "prabhat"
for i in s:
    if i =="b":
        break
    print(i)
else :
    print("dont print until it will not print name")
# Out:
# p
# r
# a

# %% [markdown]
# # while

# %%
#it will first check condition whether a condfition is true or false 
#if it is true then will execute the condition
a = 1
while a <6:
    print(a)
    a= a+1
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
a = 1
while a <5:
    print(a)
    a= a+1
# Out:
# 1
# 2
# 3
# 4

# %%
a = 1
while a<5 :
    print(a)
    if a == 4:
        break
    a=a+1
# Out:
# 1
# 2
# 3
# 4

# %%
a =1 
while a<5 :
    print(a)
    if a ==3:
        continue
    a = a+1
# Out:
# 1
# 2
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# ...

# %%
a =1 
while a<5 :
    print(a)
    a = a+1
    if a ==3:
        continue
# Out:
# 1
# 2
# 3
# 4

# %%
while a <5:
# Out:
#   File "<ipython-input-9-9cb75d5e8ddd>", line 1
#     while a <5:
#                ^
# SyntaxError: unexpected EOF while parsing

# %%
for i in l:
# Out:
#   File "<ipython-input-10-b882057075b2>", line 2
#
#     ^
# SyntaxError: unexpected EOF while parsing

# %%
for i in k:
    pass
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-3d215f8c62e0> in <module>
# ----> 1 for i in k:
#       2     pass
#
# NameError: name 'k' is not defined

# %%
while a < 4:
    break

# %%
a = 1
while a <5:
    continue
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-9b0300fef675> in <module>
#       1 a = 1
# ----> 2 while a <5:
#       3     continue
#
# KeyboardInterrupt:

# %%
for i in l:
    pass
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-864365374709> in <module>
# ----> 1 for i in l:
#       2     pass
#
# NameError: name 'l' is not defined

# %%
a = 1

# %%
range(6)
# Out:
# range(0, 6)

# %%
for i in range(6):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5

# %%
list(range(6))
# Out:
# [0, 1, 2, 3, 4, 5]

# %%
list(range(0,10,2))
# Out:
# [0, 2, 4, 6, 8]

# %%
list(range(0,10,-1))
# Out:
# []

# %%
#pyramid structure
n = 5
for i in range(0,5):
    for j in range(0,i+1):
        print("* ",end = "")
    print("\r")
# Out:
# *
# * *
# * * *
# * * * *
# * * * * *

# %%
t = (1,2,3,4,5,6,7)
t[::-1]
# Out:
# (7, 6, 5, 4, 3, 2, 1)

# %%
len(t)
# Out:
# 7

# %%
#using for loop reverse it
for i in range(len(t)-1,0,-1):
    print(t[i])
# Out:
# 7
# 6
# 5
# 4
# 3
# 2

# %%
d = {"a":"fdsfd","b":"dfscfd","c":[1,2,3,4,5],"d":(4,5,6),"e":"sudh"}

# %%
for i in d:
    print(i)
# Out:
# a
# b
# c
# d
# e

# %%
for i,j in d:
    print(i,j)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-46-30c050f35140> in <module>
# ----> 1 for i,j in d:
#       2     print(i,j)
#
# ValueError: not enough values to unpack (expected 2, got 1)

# %%
for i in d:
    print(i,d[i])
# Out:
# a fdsfd
# b dfscfd
# c [1, 2, 3, 4, 5]
# d (4, 5, 6)
# e sudh

# %%
d.items()
# Out:
# dict_items([('a', 'fdsfd'), ('b', 'dfscfd'), ('c', [1, 2, 3, 4, 5]), ('d', (4, 5, 6)), ('e', 'sudh')])

# %%
for i in d.items():
    print(i)
# Out:
# ('a', 'fdsfd')
# ('b', 'dfscfd')
# ('c', [1, 2, 3, 4, 5])
# ('d', (4, 5, 6))
# ('e', 'sudh')

# %%
s = {3,45,12,34,12,12,45,67,78,65,6,7,8,9,8,6,55}

# %%
s
# Out:
# {3, 6, 7, 8, 9, 12, 34, 45, 55, 65, 67, 78}

# %%
for i in s:
    print(i)
# Out:
# 65
# 34
# 67
# 3
# 6
# 7
# 8
# 9
# 12
# 45
# 78
# 55
